# %%
import pandas as pd

# %%
cols = ['Status of existing checking account',
        'Duration in month',
        'Credit history',
        'Purpose',
        'Credit amount',
        'Savings account/bonds',
        'Present employment since',
        'Installment rate of disposable income',
        'Personal status and sex',
        'Other debtors / guarantors',
        'Present residence since',
        'Property',
        'Age',
        'Other installment plans',
        'Housing',
        'Number of existing credits',
        'Job',
        'Number of people being liable',
        'Telephone',
        'foreign worker',
        'score'
       ]

data = pd.read_csv("german.data", sep='\s+', header=None, names = cols)
data
# Out:
#     Status of existing checking account  Duration in month Credit history  \
# 0                                   A11                  6            A34
# 1                                   A12                 48            A32
# 2                                   A14                 12            A34
# 3                                   A11                 42            A32
# 4                                   A11                 24            A33
# ..                                  ...                ...            ...
# 995                                 A14                 12            A32
# 996                                 A11                 30            A32
# 997                                 A14                 12            A32
# 998                                 A11                 45            A32
# 999                                 A12                 45            A34
#
#     Purpose  Credit amount Savings account/bonds Present employment since  \
# ...

# %%
dic = {
    'A11' : '... < 0 DM',
    'A12' : '0 <= ... < 200 DM',
    'A13' : '... >= 200 DM / salary at least 1 year',
    'A14' : 'no checking account',
    'A30' : 'no credits taken/ all credits paid back duly',
    'A31' : 'all credits at this bank paid back duly',
    'A32' : 'existing credits paid back duly till now',
    'A33' : 'delay in paying off in the past',
    'A34' : 'critical account/ other credits existing (not at this bank)',
    'A40' : 'car (new)',
    'A41' : 'car (used)',
    'A42' : 'furniture/equipment',
    'A43' : 'radio/television',
    'A44' : 'domestic appliances',
    'A45' : 'repairs',
    'A46' : 'education',
    'A47' : '(vacation - does not exist?)',
    'A48' : 'retraining',
    'A49' : 'business',
    'A410' : 'others',
    'A61' : '... < 100 DM',
    'A62' : '100 <= ... < 500 DM',
    'A63' : '500 <= ... < 1000 DM',
    'A64' : '.. >= 1000 DM',
    'A65' : 'unknown/ no savings account',
    'A71' : 'unemployed',
    'A72' : '... < 1 year',
    'A73' : '1 <= ... < 4 years',
    'A74' : '4 <= ... < 7 years',
    'A75' : '.. >= 7 years',
    'A91' : 'male : divorced/separated',
    'A92' : 'female : divorced/separated/married',
    'A93' : 'male : single',
    'A94' : 'male : married/widowed',
    'A95' : 'female : single',
    'A101' : 'none',
    'A102' : 'co-applicant',
    'A103' : 'guarantor',
    'A121' : 'real estate',
    'A122' : 'building society savings agreement/ life insurance',
    'A123' : 'car or other, not in attribute 6',
    'A124' : 'unknown / no property',
    'A141' : 'bank',
    'A142' : 'stores',
    'A143' : 'none',
    'A151' : 'rent',
    'A152' : 'own',
    'A153' : 'for free',
    'A171' : 'unemployed/ unskilled - non-resident',
    'A172' : 'unskilled - resident',
    'A173' : 'skilled employee / official',
    'A174' : 'management/ self-employed/ highly qualified employee/ officer',
    'A191' : 'none',
    'A192' : 'yes, registered under the customers name',
    'A201' : 'yes',
    'A202' : 'no'
}

data.replace(dic, inplace=True)
data
# Out:
#     Status of existing checking account  Duration in month  \
# 0                            ... < 0 DM                  6
# 1                     0 <= ... < 200 DM                 48
# 2                   no checking account                 12
# 3                            ... < 0 DM                 42
# 4                            ... < 0 DM                 24
# ..                                  ...                ...
# 995                 no checking account                 12
# 996                          ... < 0 DM                 30
# 997                 no checking account                 12
# 998                          ... < 0 DM                 45
# 999                   0 <= ... < 200 DM                 45
#
#                                         Credit history              Purpose  \
# 0    critical account/ other credits existing (not ...     radio/television
# 1             existing credits paid back duly till now     radio/television
# ...

# %%
data.to_csv("german_processed.csv", index = False)

# %%
import seaborn as sns
import matplotlib.pyplot as plt
#plt.figure(figsize=(15,50))
df = data[['Credit history','Present employment since','Personal status and sex','score']]

sns.catplot(x='Credit history',y='Present employment since',col='Personal status and sex',kind='swarm',hue='score',col_wrap=1,height=4, aspect=5,data=df)
# Out:
# /Users/fahadahmad/opt/anaconda3/lib/python3.9/site-packages/seaborn/categorical.py:1296: UserWarning: 21.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /Users/fahadahmad/opt/anaconda3/lib/python3.9/site-packages/seaborn/categorical.py:1296: UserWarning: 35.2% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /Users/fahadahmad/opt/anaconda3/lib/python3.9/site-packages/seaborn/categorical.py:1296: UserWarning: 18.8% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
data.describe()
# Out:
#        Duration in month  Credit amount  \
# count        1000.000000    1000.000000
# mean           20.903000    3271.258000
# std            12.058814    2822.736876
# min             4.000000     250.000000
# 25%            12.000000    1365.500000
# 50%            18.000000    2319.500000
# 75%            24.000000    3972.250000
# max            72.000000   18424.000000
#
#        Installment rate of disposable income  Present residence since  \
# count                            1000.000000              1000.000000
# mean                                2.973000                 2.845000
# std                                 1.118715                 1.103718
# min                                 1.000000                 1.000000
# 25%                                 2.000000                 2.000000
# 50%                                 3.000000                 3.000000
# 75%                                 4.000000                 4.000000
# ...

# %% [markdown]
# ### Univariate Analysis

# %% [markdown]
# #### Observation: Number of applicants based on Age

# %%
sns.histplot(data["Age"])
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Count'>

# %% [markdown]
# ##### Analysis: Reasonably enough, younger generation has a higher propensity to take credit for diverse range of needs like education, personal consumption or entreprenuerial purposes.

# %% [markdown]
# #### Observation: Foreign workers credit score

# %%
sns.countplot(x=data["foreign worker"], hue=data["score"])
# Out:
# <AxesSubplot:xlabel='foreign worker', ylabel='count'>

# %% [markdown]
# ##### Analysis: Most applicants are Foreign workers but their credit score is proportionally better than that of non-foreign workers

# %% [markdown]
# #### Observation: Credit score segragated by Sex and marital status

# %%
sns.countplot(x=data["Personal status and sex"], hue=data["score"])
plt.xticks(rotation=30, ha='right')
# Out:
# (array([0, 1, 2, 3]),
#  [Text(0, 0, 'male : single'),
#   Text(1, 0, 'female : divorced/separated/married'),
#   Text(2, 0, 'male : divorced/separated'),
#   Text(3, 0, 'male : married/widowed')])

# %% [markdown]
# ##### Analysis: Most applicants are Male:single

# %% [markdown]
# #### Observation: Credit score segregated by Present Employment since

# %%
sns.countplot(x=data["Present employment since"], hue=data["score"])
plt.xticks(rotation=30, ha='right')
# Out:
# (array([0, 1, 2, 3, 4]),
#  [Text(0, 0, '.. >= 7 years'),
#   Text(1, 0, '1 <= ... < 4 years'),
#   Text(2, 0, '4 <= ... < 7 years'),
#   Text(3, 0, 'unemployed'),
#   Text(4, 0, '... < 1 year')])

# %% [markdown]
# ##### Analysis: Unemployed and those employed for <1 year have proportionally higher credit risk. While most applicants are those who are employed for last 1 to 4 years.

# %% [markdown]
# #### Observation: Credit score segregated by the Number of people being liable

# %%
sns.countplot(x=data["Number of people being liable"], hue=data["score"])
# Out:
# <AxesSubplot:xlabel='Number of people being liable', ylabel='count'>

# %% [markdown]
# ##### Analysis: Most applicants have 1 person being liable

# %% [markdown]
# #### Observation: Represent credit amount in a boxplot

# %%
sns.boxplot(x=data["Credit amount"])
# Out:
# <AxesSubplot:xlabel='Credit amount'>

# %% [markdown]
# #### Observation: Represent Duration in month in a boxplot

# %%
sns.boxplot(x=data["Duration in month"])
# Out:
# <AxesSubplot:xlabel='Duration in month'>

# %% [markdown]
# #### Observation: Credit score segregated by the Number of existing credit

# %%
sns.countplot(x=data["Number of existing credits"], hue=data["score"])
# Out:
# <AxesSubplot:xlabel='Number of existing credits', ylabel='count'>

# %% [markdown]
# ##### Analysis: Most applicants have 1 existing credits

# %% [markdown]
# #### Observation: Credit score partitioned by credit history

# %%
sns.countplot(x=data["Credit history"], hue=data["score"])
plt.xticks(rotation=30, ha='right')
# Out:
# (array([0, 1, 2, 3, 4]),
#  [Text(0, 0, 'critical account/ other credits existing (not at this bank)'),
#   Text(1, 0, 'existing credits paid back duly till now'),
#   Text(2, 0, 'delay in paying off in the past'),
#   Text(3, 0, 'no credits taken/ all credits paid back duly'),
#   Text(4, 0, 'all credits at this bank paid back duly')])

# %% [markdown]
# ##### Analysis: Applicants with credit history 'no credits taken ...' and 'all credits at this bank...' are risky and have higher default risk

# %% [markdown]
# #### Observation: Credit score partitioned by Job

# %%
sns.countplot(x=data["Job"], hue=data["score"])
plt.xticks(rotation=30, ha='right')
# Out:
# (array([0, 1, 2, 3]),
#  [Text(0, 0, 'skilled employee / official'),
#   Text(1, 0, 'unskilled - resident'),
#   Text(2, 0, 'management/ self-employed/ highly qualified employee/ officer'),
#   Text(3, 0, 'unemployed/ unskilled - non-resident')])

# %% [markdown]
# ##### Analysis: As expected most applicants are skilled employee/official while the least number oif applicants are unemployed/unskilled non-resident.

# %% [markdown]
# ### Bivariate Analysis

# %% [markdown]
# #### Covariance Matrix for numerical attributes

# %%
df_corr = data.corr()
sns.heatmap(df_corr, annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Chi-square for categorical attributes

# %%
import numpy as np
import scipy.stats as stats
from scipy.stats import chi2_contingency

cat_df = pd.DataFrame(data, columns=['Status of existing checking account',
        'Credit history',
        'Purpose',
        'Savings account/bonds',
        'Present employment since',
        'Personal status and sex',
        'Other debtors / guarantors',
        'Present residence since',
        'Property',
        'Other installment plans',
        'Housing',
        'Job',
        'Telephone',
        'foreign worker',
        'score'])

features = ['Status of existing checking account',
        'Credit history',
        'Purpose',
        'Savings account/bonds',
        'Present employment since',
        'Personal status and sex',
        'Other debtors / guarantors',
        'Present residence since',
        'Property',
        'Other installment plans',
        'Housing',
        'Job',
        'Telephone',
        'foreign worker']

# The function 'chi2_contingency' computes the chi-square statistic and p-value for the hypothesis test of 
# independence of the observed frequencies in the contingency table observed. The expected frequencies are 
# computed based on the marginal sums under the assumption of independence
for f in features:
    X= cat_df[f].astype(str)
    Y= cat_df["score"].astype(str)
    df_observed = pd.crosstab(Y,X)
    chi2, pval, dof, expected = stats.chi2_contingency(df_observed.values)

    if pval<0.05:
        print("{0} is IMPORTANT \n".format(f))
    else:
        print("{0} is NOT IMPORTANT \n".format(f))
# Out:
# Status of existing checking account is IMPORTANT
#
# Credit history is IMPORTANT
#
# Purpose is IMPORTANT
#
# Savings account/bonds is IMPORTANT
#
# Present employment since is IMPORTANT
#
# Personal status and sex is IMPORTANT
#
# Other debtors / guarantors is IMPORTANT
#
# Present residence since is NOT IMPORTANT
#
# Property is IMPORTANT
#
# Other installment plans is IMPORTANT
#
# Housing is IMPORTANT
#
# Job is NOT IMPORTANT
#
# Telephone is NOT IMPORTANT
#
# foreign worker is IMPORTANT

# %% [markdown]
# #### Note: After analysing the data contained in the feature 'Present resisdence since' we can safely consider it as a categorical attribute

# %% [markdown]
# ## Multivariate analysis for numerical attributes

# %% [markdown]
# ### Principle Component analysis

# %%
from sklearn.decomposition import PCA

pca_df = pd.DataFrame(data, columns=['Duration in month', 'Credit amount', 'Installment rate of disposable income',
                                              'Age','Number of existing credits',
                                              'Number of people being liable'])

Z_score = (pca_df.to_numpy()-pca_df.to_numpy().mean(axis=0))/pca_df.to_numpy().std(axis=0)

pca = PCA().fit(Z_score)
                                          
PC_values = np.arange(pca.n_components_) + 1
plt.plot(PC_values, pca.explained_variance_ratio_)
plt.title('Principal Component Analysis')
plt.xlabel('Principal Component')
plt.ylabel('Proportion of Variance Explained')
plt.show()

# %% [markdown]
# #### From the graph we can assert that the first 5 components contain 95% of information and hence the last component can be ignored in order to improve the performance at the cost of some accuracy
